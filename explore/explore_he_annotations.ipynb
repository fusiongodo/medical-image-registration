# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import json
import sys

import sys
import importlib

sys.path.append("..")
sys.path.append("../pretraining_compare_detectors")

import conf
importlib.reload(conf)

sys.path.append(str(Path.cwd().parent.parent))

import conf

HE_KEYPOINT_ANNOTATION_PATH = conf.HE_KEYPOINT_ANNOTATION_PATH
with open(HE_KEYPOINT_ANNOTATION_PATH, "r", encoding="utf-8") as f:
    jobs = json.load(f)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pair_id = 0
crop_depth = 3
x_idx = 7
y_idx = 0

matching = [j for j in jobs if j["crop_depth"] == crop_depth and j["x_idx"] == x_idx and j["y_idx"] == y_idx and j["pair_id"] == pair_id]

# %%
matching
# Out:
# []
